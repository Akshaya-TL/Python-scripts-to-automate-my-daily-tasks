# %%
import pandas as pd

# %%
qbank = pd.read_csv(r'qbankjava.csv')

# %%
qbank.head()
# Out:
#    S.No dept Subject        Topic  level  \
# 0   1.0   IT    JAVA  Java Basics    1.0
# 1   2.0   IT    JAVA  Java Basics    1.0
# 2   3.0   IT    JAVA  Java Basics    1.0
# 3   4.0   IT    JAVA  Java Basics    1.0
# 4   5.0   IT    JAVA  Java Basics    2.0
#
#                                             Question  \
# 0                 Java Source Code is compiled into?
# 1  Which of the following is not OOPS concept in ...
# 2                Which statement is true about java?
# 3  Which component is responsible to optimize byt...
# 4  Which of the below is invalid identifier with ...
#
#                                   Choice 1  \
# 0                                     .Obj
# 1                              Inheritance
# 2  Sequence dependent programming language
# 3                                      JVM
# 4                                   public
#
#                                     Choice 2  \
# 0                                Source Code
# 1                              Encapsulation
# 2  Platform independent programming language
# 3                                        JDK
# 4                                     static
#
#                                   Choice 3  \
# 0                                Byte Code
# 1                             Polymorphism
# 2  Platform dependent programming language
# 3                                      JIT
# 4                                  private
#
#                               Choice 4  Correct Choice   \
# 0                                 .Exe              3.0
# 1                   Exception Handling              4.0
# 2  Code dependent programming language              2.0
# 3                                  JRE              3.0
# 4                                final              3.0
#
#                                         Explanation            Reference  \
# 0  When we compile the Java program the compiler ...         c4learn.com
# 1  There are 4 OOPS concepts in Java. Inheritance...  www.sanfoundry.com
# 2  Java is called ‘Platform Independent Language’...  www.sanfoundry.com
# 3  JIT optimizes bytecode to machine specific lan...  www.sanfoundry.com
# 4  main method cannot be private as it is invoked...  www.sanfoundry.com
#
#    Unit Number
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
question = list(qbank['Question'])
options1 = list(qbank['Choice 1'])
options2 = list(qbank['Choice 2'])
options3 = list(qbank['Choice 3'])
options4 = list(qbank['Choice 4'])
answers = list(qbank['Correct Choice '])
reason = list(qbank['Explanation '])

# %%
req = list(zip(question, options1, options2, options3, options4, answers, reason))

# %%
# !pip install python-docx
import docx
from docx import *
my_doc = docx.Document()
my_doc.add_paragraph("MCQs")
my_doc.save("C:/docsByMe/mcqs.docx")
# Out:
# Requirement already satisfied: python-docx in c:\users\akshaya\anaconda3\lib\site-packages (0.8.11)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\akshaya\anaconda3\lib\site-packages (from python-docx) (4.5.0)

# %%
i = 1
for x in req[:181]:
    my_doc.add_paragraph("Q"+str(i)+str(x[0]))
    my_doc.add_paragraph("1. " + str(x[1]))
    my_doc.add_paragraph("2. " + str(x[2]))
    my_doc.add_paragraph("3. " + str(x[3]))
    my_doc.add_paragraph("4. " + str(x[4]))
    my_doc.add_paragraph("correct: " + str(int(x[5])))
    my_doc.add_paragraph("reason: " + str(x[6]))
    my_doc.save("C:/docsByMe/mcqs.docx")
    i += 1

# %%
i = 1
for x in req[:181]:
    print("Q",i,x[0])
    print("1. ", x[1])
    print("2. ", x[2])
    print("3. ", x[3])
    print("4. ", x[4])
    print("correct: ", x[5])
    print("reason: ", x[6])
    i += 1
